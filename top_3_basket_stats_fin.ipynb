# %% [markdown]
# # Web scraping the top 3 advanced statistical metrics in basketball.

# %% [markdown]
# *The last code review date: March 12, 2024.*

# %% [markdown]
# ## Introduction
#
# Traditional statistical metrics in basketball often fail to provide a comprehensive reflection of reality on the court. While a player may exhibit a stellar offensive performance, sinking shots with high accuracy, defensive lapses could result in the team conceding more points than the player's offensive contributions. To address this gap, advanced statistical metrics have emerged, aiming to offer a nuanced understanding of player impact on team performance. In this analysis, we delve into three cutting-edge metrics highly regarded in the basketball community: LEBRON, EPM, and DARKO.
#
# ### LEBRON
# - **Full Title:** Luck-adjusted Player Estimate using a Box prior Regularized ON-off
# - **Concept:** This metric leverages a player's influence on team Plus-minus, employing weighted boxPIPM coefficients and RAPM methodology to provide a holistic assessment of their impact on the game, with adjustments made for luck factors.
#
# ### EPM
# - **Full Title:** Estimated Plus-Minus
# - **Concept:** EPM evaluates a player's impact on the team's performance when they're on and off the court, incorporating Bayesian prior values to quantify their contribution.
#
# ### DARKO
# - **Full Title:** Daily Plus-Minus
# - **Concept:** DARKO introduces a machine learning-based scoring prediction system for basketball players, integrating time series data and sample size considerations. Its Bayesian model forecasts all aspects of box score estimation, showcasing a player's projected skill development over time. Notably, DARKO surpasses other publicly available indicators in predictive accuracy, as measured by root mean square error (RMSE).
#
# These metrics offer distinct methodologies for assessing a player's influence on team performance. The ensuing table presents player ratings across each metric, culminating in an average score. By examining the player's ranking in each metric—LEBRON, EPM, and DARKO—and calculating the average, we minimize potential evaluation discrepancies inherent in single-model approaches. This consolidated ranking, represented in the RANK_TOP3_AVG column, serves as a reliable benchmark for gauging player performance based on advanced metrics.
#
# This metric not only caters to basketball enthusiasts seeking a deeper understanding of player dynamics but also provides valuable insights for industry experts navigating the intricacies of on-court performance analysis and prediction.

# %%
import math  # Importing math for mathematical functions
import datetime  # Importing datetime for working with dates and times
import warnings  # Importing warnings for handling warning messages
import time  # Importing time for working with time-related functions

import requests  # Importing the requests module for sending HTTP requests
from bs4 import BeautifulSoup  # Importing BeautifulSoup from bs4 for parsing HTML and XML documents
import pandas as pd  # Importing pandas for data manipulation and analysis
from functools import reduce  # Importing the 'reduce' function from the 'functools' module.

import selenium.webdriver  # Importing WebDriver module from Selenium for web automation
from selenium import webdriver # Importing the webdriver module from Selenium
from selenium.webdriver.common.by import By  # Importing the By class from Selenium for locating elements by various strategies
from selenium.webdriver.common.keys import Keys  # Importing the Keys class from Selenium for keyboard actions
from selenium.webdriver.support.ui import WebDriverWait  # Importing WebDriverWait from Selenium for waiting for certain conditions
from selenium.webdriver.support import expected_conditions as EC  # Importing expected_conditions from Selenium for defining expected conditions

from io import StringIO  # Importing StringIO for reading and writing strings as files
from lxml import etree  # Importing etree from lxml for processing XML and HTML

# %%
# Suppressing SettingWithCopyWarning warnings
pd.options.mode.chained_assignment = None  # default='warn'

# Set the warning level to "ignore"
warnings.simplefilter(action='ignore', category=FutureWarning, append=True)

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# ## DARKO (Daily Plus-Minus)

# %%
def scrape_data_DARKO(number):
    """
    Scrapes data from a webpage using Selenium WebDriver.

    Args:
    number (int): Number of times to click the "Next" button to scrape data from multiple pages.

    Returns:
    pandas.DataFrame: Scraped data.

    """
    # Set up Chrome options
    options = webdriver.ChromeOptions()
    options.add_argument('headless')  # Run Chrome in the Chrome Headless Mode

    # Use a context manager for the Chrome WebDriver
    with webdriver.Chrome(options=options) as driver:
        wait = WebDriverWait(driver, 12)  # Set up WebDriverWait

        url_DARKO = 'https://apanalytics.shinyapps.io/DARKO/'
        driver.get(url_DARKO)  # Open the specified URL

        # Click on the "Current Player Skill Projections" tab
        current_player_skill_projections_tab = wait.until(EC.presence_of_element_located((By.LINK_TEXT, "Current Player Skill Projections")))
        current_player_skill_projections_tab.click()

        start_time = time.time()  # Record the start time
        while time.time() - start_time < 5:
            pass  # Wait for 5 seconds for the page to load

        # Get the HTML source after clicking the tab
        html_on_Current_Player_Skill_Projections = driver.page_source
        soup_after_click = BeautifulSoup(html_on_Current_Player_Skill_Projections, "html.parser")

        # Find the table with id "DataTables_Table_0"
        table = soup_after_click.find('table', {'id': 'DataTables_Table_0'})

        # Read the table into a DataFrame
        df = pd.read_html(str(table))[0]
        
        # Loop to click on the "Next" button and scrape data from multiple pages
        for _ in range(number):
            next_button = wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "paginate_button.next")))
            next_button.click()

            start_time = time.time()
            while time.time() - start_time < 3:
                pass  # Wait for 3 seconds

            # Get the HTML source after clicking the "Next" button
            html_after_next_click = driver.page_source
            soup_after_next_click = BeautifulSoup(html_after_next_click, "html.parser")

            # Find the table after clicking the "Next" button and convert it to a DataFrame
            table_after_next_click = soup_after_next_click.find('table', {'id': 'DataTables_Table_0'})
            df_next = pd.read_html(str(table_after_next_click))[0]
            df = pd.concat([df, df_next], ignore_index=True)

    return df

# Call the scrape_data function with a specified number of iterations
df_DARKO = scrape_data_DARKO(55)

# Drop rows with all NaN values
df_DARKO = df_DARKO.dropna(how='all')

# Drop duplicate rows
df_DARKO = df_DARKO.drop_duplicates()

# Convert the 'DPM' column to float
df_DARKO['DPM'] = df_DARKO['DPM'].astype(float)

# Add a 'DPM_RANK' column with the rank of values in the 'DPM' column
df_DARKO['DPM_RANK'] = df_DARKO['DPM'].rank(ascending=False)

# Convert the 'DPM_RANK' column to integer
df_DARKO['DPM_RANK'] = df_DARKO['DPM_RANK'].astype(int)

# %% [markdown]
# ## EPM (Estimated Plus-Minus)

# %%
def scrape_epm_data_epm():
    """
    Scrape data from the EPM website.

    Returns:
        pandas.DataFrame: Scraped data.
    """
    # Browser options (for running the browser with the Chrome Headless Mode)
    options = webdriver.ChromeOptions()
    options.add_argument('headless')

    # Initializing the browser driver
    driver = webdriver.Chrome(options=options)

    # Website URL
    url_epm = 'https://dunksandthrees.com/epm'

    # Opening the website
    driver.get(url_epm)

    # Waiting for the table to load
    table = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CSS_SELECTOR, 'div.table-wrap table.main')))

    # Extracting data from the first 10 rows
    rows_data_epm = []
    for row in table.find_elements(By.CSS_SELECTOR, 'tr.svelte-blwps1')[:10]:
        cells = row.find_elements(By.CLASS_NAME, 'svelte-blwps1')
        row_data_epm = [cell.text for cell in cells]
        rows_data_epm.append(row_data_epm)

    # Scrolling the table and extracting data after each scroll
    scroll_pixels = 360
    row_height = 36
    for scroll_count in range(1, 48):  # Scroll 48 times
        # Execute JavaScript to scroll the table
        driver.execute_script(f"document.querySelector('div.table-wrap').scrollTop += {scroll_pixels}")
        # Wait for new data to load
        WebDriverWait(driver, 10).until(EC.invisibility_of_element_located((By.CSS_SELECTOR, 'div.loading')))

        # Extract data from table cells
        for row in table.find_elements(By.CSS_SELECTOR, 'tr.svelte-blwps1')[scroll_count*10:scroll_count*10+10]:
            cells = row.find_elements(By.CLASS_NAME, 'svelte-blwps1')
            row_data_epm = [cell.text for cell in cells]
            rows_data_epm.append(row_data_epm)

    # Close the browser
    driver.quit()

    # Remove the first two nested lists
    rows_data_epm = rows_data_epm[2:]

    # Convert to a DataFrame without column names
    df_epm = pd.DataFrame(rows_data_epm)

    return df_epm

# Scraping data using a function named scrape_epm_data_epm() and assigning the result to the DataFrame df_epm
df_epm = scrape_epm_data_epm()

# %%
def shift_rows(df, condition, num_columns_to_shift):
    """
    Shifts rows in a DataFrame based on the given condition and number of columns to shift.
    
    Parameters:
        df (DataFrame): The DataFrame to operate on.
        condition (Series): The condition to filter rows.
        num_columns_to_shift (int): The number of columns to shift.
    
    Returns:
        DataFrame: The DataFrame with shifted rows.
    """
    # Filtering rows based on condition to get subset of rows
    filtered_rows_1 = df[df[31].isnull()]
    filtered_rows_2 = filtered_rows_1.loc[condition]

    # Checking if both original and filtered subsets are not empty
    if not filtered_rows_1.empty and not filtered_rows_2.empty:
        # Iterating through rows of filtered subset and shifting values to the right
        for index, row in filtered_rows_2.iterrows():
            for i in range(num_columns_to_shift, len(row) - 2):
                df_epm.loc[index, i + 2] = row[i]
                
    return df_epm


# Apply the function to shift rows for players without 3p% based on specified conditions
df_epm = shift_rows(df_epm, (df_epm[13] != '') & 
                            (df_epm[16] != '') & 
                            (df_epm[19] == ''), 20)

# Apply function with condition 2 for players without FT% based on specified conditions
df_epm = shift_rows(df_epm, (df_epm[13] != '') & 
                            (df_epm[19] != '') & 
                            (df_epm[22] == ''), 23)
# Apply the function to shift rows for players without mid% based on specified conditions
df_epm = shift_rows(df_epm, (df_epm[13] != '') & 
                            (df_epm[17] != '') & 
                            (df_epm[16] == ''), 18)
# Apply the function to shift rows for players without mid% and 3p% based on specified conditions
df_epm = shift_rows(df_epm, (df_epm[13] != '') & 
                            (df_epm[16] == '') & 
                            (df_epm[17] == '') & 
                            (df_epm[19] == ''), 20)
# Apply the function to shift rows for players without mid%, 3p% and FT% based on specified conditions
df_epm = shift_rows(df_epm, (df_epm[13] != '') & 
                            (df_epm[16] == '') & 
                            (df_epm[17] == '') & 
                            (df_epm[19] == '') & 
                            (df_epm[20] == ''), 20)
# Apply the function to shift rows for players without rimn %, mid% and FT% based on specified conditions
df_epm = shift_rows(df_epm, (df_epm[13] == '') & 
                            (df_epm[16] == '') & 
                            (df_epm[17] == '') & 
                            (df_epm[19] != '') & 
                            (df_epm[23] != ''), 23)

# %%
# Specify the column numbers to be dropped
columns_epm_to_drop = [11, 12, 14, 15, 17, 18, 20, 21, 23, 24]

# Drop columns by the specified indexes
df_epm.drop(columns=columns_epm_to_drop, inplace=True)

# Specify the column names
column_names_epm = ['Player_all_info', 'Player', 'GP', 'MPG', 'USG', '+/- OFF_EPM', '+/- DEF_EPM', 
                'EPM', 'Estimated_wins', 'TS%', 'eFG%', 'FG at te rim', 'FG% fron midrannge', 
                '3PT%', 'FT%', 'OR%', 'DR%', 'AST%', 'TO%', 'ST%', 'BL%', 'Rank_EPM']

# Set the column names
df_epm.columns = column_names_epm

# Split the "Player_all_info" column into multiple columns
df_epm[['Player', 'Team', 'Position', 'Age']] = df_epm['Player_all_info'].str.split('\n|·', expand=True)[[0, 1, 2, 3]]

# List of columns to process
columns_to_process = ['GP', 'MPG', 'USG', '+/- OFF_EPM', '+/- DEF_EPM', 
                      'EPM', 'Estimated_wins', 'TS%', 'eFG%', 'FG at te rim', 
                      'FG% fron midrannge', '3PT%', 'FT%', 'OR%', 'DR%', 
                      'AST%', 'TO%', 'ST%', 'BL%']

# Apply the operation to split and select the first part for each value in the specified columns
df_epm[columns_to_process] = df_epm[columns_to_process].apply(lambda x: x.str.split('\n').str[0])

# New order of columns
new_column_order = ['Player', 'Team', 'Position', 'Age', 'GP', 'MPG', 'USG', '+/- OFF_EPM', '+/- DEF_EPM', 
                    'EPM', 'Estimated_wins', 'TS%', 'eFG%', 'FG at te rim', 'FG% fron midrannge', 
                    '3PT%', 'FT%', 'OR%', 'DR%', 'AST%', 'TO%', 'ST%', 'BL%', 'Rank_EPM']

# Select and reorder columns
df_epm = df_epm[new_column_order]

# Convert empty strings to NaN and convert values to numeric format
columns_to_convert_float = ['MPG', 'USG', 'TS%', 'eFG%', 'FG at te rim', 'FG% fron midrannge', 
                            '3PT%', 'FT%', 'OR%', 'DR%', 'AST%', 'TO%', 'ST%', 'BL%']
df_epm[columns_to_convert_float] = df_epm[columns_to_convert_float].apply(pd.to_numeric, errors='coerce')

# Reset index and adjust index values
df_epm.reset_index(drop=True, inplace=True)
df_epm.index += 1

# Convert 'Rank_Lebron' column to integer data type
df_epm['Rank_EPM'] = df_epm['Rank_EPM'].astype(int)

# %% [markdown]
# ## LEBRON (Luck-adjusted player Estimate using a Box prior Regularized ON-off)

# %%
# URL of the page to be parsed
url_lebron = 'https://www.bball-index.com/lebron-database/'

# Send a GET request to the specified URL and save the page content
response_lebron = requests.get(url_lebron)

soup_lebron = BeautifulSoup(response_lebron.content, 'html.parser')
table_lebron = soup_lebron.find('table', {'id': 'table_1'})

data_lebron = []
for row in table_lebron.find_all('tr'):
   cols = row.find_all(['th', 'td'])
   cols = [ele.text.strip() for ele in cols]
   data_lebron.append([ele for ele in cols if ele])

# Creating DataFrame using Pandas
df_lebron = pd.DataFrame(data_lebron[1:], columns=data_lebron[0])

# %%
# Drop unnecessary columns and filter out rows with specific values
df_lebron = df_lebron.drop(['bref_id', 'NBA ID'], axis=1).query('Minutes != "Pos" and Age != "-0.30"')

# Convert selected columns to numeric data type
columns_to_convert_float_lebron = ['LEBRON', 'O-LEBRON', 'D-LEBRON', 'boxLEBRON', 'boxOLEBRON', 'boxDLEBRON']
df_lebron[columns_to_convert_float_lebron] = df_lebron[columns_to_convert_float_lebron].apply(pd.to_numeric, errors='coerce')

# Convert a column to float after removing commas
df_lebron["LEBRON Contract Value"] = df_lebron["LEBRON Contract Value"].str.replace(',', '').astype(float)

# Filter rows for the 2023-24 season
df_lebron_2023_2024 = df_lebron[df_lebron['Season'] == '2023-24']

# Create a dictionary to store last year's LEBRON values for each player
lebron_last_year_dict_LEBRON = {}
for player in df_lebron_2023_2024['Player'].unique():
    player_row = df_lebron[(df_lebron['Player'] == player) & (df_lebron['Season'] == '2022-23')]
    if not player_row.empty:
        lebron_last_year_dict_LEBRON[player] = player_row.iloc[0]['LEBRON']
    else:
        lebron_last_year_dict_LEBRON[player] = float('nan')

# Map last year's LEBRON values to the DataFrame
df_lebron_2023_2024.loc[:, 'LEBRON_last_year'] = df_lebron_2023_2024['Player'].map(lebron_last_year_dict_LEBRON)

# Create dictionaries to store last year's O-LEBRON and D-LEBRON values for each player
lebron_last_year_dicts = {'O-LEBRON': {}, 'D-LEBRON': {}}
for player in df_lebron_2023_2024['Player'].unique():
    for lebron_type in ['O-LEBRON', 'D-LEBRON']:
        player_row = df_lebron[(df_lebron['Player'] == player) & (df_lebron['Season'] == '2022-23')]
        if not player_row.empty:
            lebron_last_year_dicts[lebron_type][player] = player_row.iloc[0][lebron_type]
        else:
            lebron_last_year_dicts[lebron_type][player] = float('nan')

# Map last year's O-LEBRON and D-LEBRON values to the DataFrame
for lebron_type in ['O-LEBRON', 'D-LEBRON']:
    df_lebron_2023_2024.loc[:, f'{lebron_type}_last_year'] = df_lebron_2023_2024['Player'].map(lebron_last_year_dicts[lebron_type])

# Calculate rank based on LEBRON values
df_lebron_2023_2024['Rank_Lebron'] = df_lebron_2023_2024['LEBRON'].rank(ascending=False, method='min')

# Reorder columns in the DataFrame
new_order_2023_2024 = ['Player', 'Season', 'Team', 'Rank_Lebron', 'Offensive Archetype', 'Minutes', 'Games', 'Pos', 'Age', 'LEBRON', 'LEBRON_last_year', 'O-LEBRON',
                       'O-LEBRON_last_year', 'D-LEBRON', 'D-LEBRON_last_year', 'WAR', 'LEBRON Contract Value', 'boxLEBRON', 'boxOLEBRON', 'boxDLEBRON']
df_lebron_2023_2024 = df_lebron_2023_2024.reindex(columns=new_order_2023_2024)

# Sort DataFrame by LEBRON values
df_lebron_2023_2024 = df_lebron_2023_2024.sort_values(by='LEBRON', ascending=False)

# Reset index of the DataFrame
df_lebron_2023_2024.reset_index(drop=True, inplace=True)
df_lebron_2023_2024.index += 1

# Convert 'Rank_Lebron' column to integer data type
df_lebron_2023_2024['Rank_Lebron'] = df_lebron_2023_2024['Rank_Lebron'].astype(int)

# %% [markdown]
# ## Creating a unified table for three metrics

# %%
# Merging all DataFrames at once
merged_df = df_epm.merge(df_DARKO, on='Player', how='left')
df_top_3_stats = merged_df.merge(df_lebron_2023_2024, on='Player', how='left')

# Convert 'Rank_Lebron' column to integer data type
df_epm['Rank_EPM'] = df_epm['Rank_EPM'].astype(int)

# Calculate the average of the ranks for 'Rank_EPM', 'Rank_Lebron', and 'DPM_RANK' columns.
# Add a new column 'RANK_TOP3_AVG' to store these average values.
df_top_3_stats['RANK_TOP3_AVG'] = df_top_3_stats[['Rank_EPM', 'Rank_Lebron', 'DPM_RANK']].mean(axis=1)

# Sort the DataFrame 'df_top_3_stats' based on the values in the 'RANK_TOP3_AVG' column in ascending order.
df_top_3_stats = df_top_3_stats.sort_values(by='RANK_TOP3_AVG')

# Removing columns from the DataFrame
columns_to_drop = ['Team_x', 'Experience', 'Season', 'Team', 'Minutes', 'Games', 'Pos', 'Age_y', 'FG at te rim', 'FG% fron midrannge', '3PT%', 'FT%_x', 'OR%', 'DR%', 'AST%_x', 'TO%', 'ST%', 'BL%', 'USG%']
df_top_3_stats.drop(columns=columns_to_drop, inplace=True)

# Calculating the mean of three ranking columns and creating a new column for the average rank
df_top_3_stats['RANK_TOP3_AVG'] = df_top_3_stats[['Rank_EPM', 'Rank_Lebron', 'DPM_RANK']].mean(axis=1)
df_top_3_stats= df_top_3_stats.sort_values(by='RANK_TOP3_AVG')

# Calculating improvements for LeBron-related stats compared to last year
df_top_3_stats['LEBRON_Improvement'] = df_top_3_stats['LEBRON'] - df_top_3_stats['LEBRON_last_year']
df_top_3_stats['LEBRON_Improvement_O'] = df_top_3_stats['O-LEBRON'] - df_top_3_stats['O-LEBRON_last_year']
df_top_3_stats['LEBRON_Improvement_D'] = df_top_3_stats['D-LEBRON'] - df_top_3_stats['D-LEBRON_last_year']

desired_columns = [
    'Player', 'Position', 'Offensive Archetype', 'Team_y', 'Age_x', 'GP', 'MPG', 'USG', 'RANK_TOP3_AVG',
    'Rank_EPM', 'DPM_RANK', 'Rank_Lebron', 'LEBRON_Improvement', 'LEBRON_Improvement_O', 'LEBRON_Improvement_D', 'DPM Improvement',
    '+/- OFF_EPM', '+/- DEF_EPM', 'EPM', 'Estimated_wins', 'DPM', 'O-DPM', 'D-DPM', 'Box DPM', 'Box O-DPM', 'Box D-DPM',
    'LEBRON', 'LEBRON_last_year', 'O-LEBRON', 'O-LEBRON_last_year', 'D-LEBRON', 'D-LEBRON_last_year', 'WAR',
    'LEBRON Contract Value', 'boxLEBRON', 'boxOLEBRON', 'boxDLEBRON', 'TS%', 'eFG%', 'FGA/100', 'FG2%', 'FG3A/100',
    'FG3%', 'FG3ARate%', 'RimFGA/100', 'RimFG%', 'FTA/100', 'FT%_y', 'FTARate%', 'REB/100', 'AST/100', 'AST%_y',
    'BLK/100', 'BLK%', 'STL/100', 'STL%', 'TOV/100'
]

# Selecting desired columns from DataFrame df_top_3_stats
df_top_3_stats = df_top_3_stats[desired_columns]

# Renaming columns of DataFrame
df_top_3_stats = df_top_3_stats.rename(columns={'Team_y': 'Team', 'Age_x': 'Age', 'FT%_y': 'FT%', 'AST%_y': 'AST%'})

# Defining the second-level columns
columns = pd.MultiIndex.from_tuples([
    ('Player', 'Player'),
    ('Player_info', 'Position'),
    ('Player_info', 'Offensive Archetype'),
    ('Player_info', 'Team'),
    ('Player_info', 'Age'),
    ('Player_info', 'GP'),
    ('Player_info', 'MPG'),
    ('Player_info', 'USG'),
    ('Advanced_stats', 'RANK_TOP3_AVG'),
    ('Advanced_stats', 'Rank_EPM'),
    ('Advanced_stats', 'DPM_RANK'),
    ('Advanced_stats', 'Rank_Lebron'),
    ('Improve_last_year', 'LEBRON_Improvement'),
    ('Improve_last_year', 'LEBRON_Improvement_O'),
    ('Improve_last_year', 'LEBRON_Improvement_D'),
    ('Improve_last_year', 'DPM Improvement'),
    ('EPM', '+/- OFF_EPM'),
    ('EPM', '+/- DEF_EPM'),
    ('EPM', 'EPM'),
    ('EPM', 'Estimated_wins'),
    ('DARKO', 'DPM'),
    ('DARKO', 'O-DPM'),
    ('DARKO', 'D-DPM'),
    ('DARKO', 'Box DPM'),
    ('DARKO', 'Box O-DPM'),
    ('DARKO', 'Box D-DPM'),
    ('Lebron_stats', 'LEBRON'),
    ('Lebron_stats', 'LEBRON_last_year'),
    ('Lebron_stats', 'O-LEBRON'),
    ('Lebron_stats', 'O-LEBRON_last_year'),
    ('Lebron_stats', 'D-LEBRON'),
    ('Lebron_stats', 'D-LEBRON_last_year'),
    ('Lebron_stats', 'WAR'),
    ('Lebron_stats', 'LEBRON Contract Value'),
    ('Lebron_stats', 'boxLEBRON'),
    ('Lebron_stats', 'boxOLEBRON'),
    ('Lebron_stats', 'boxDLEBRON'),
    ('Basic_Stats', 'TS%'),
    ('Basic_Stats', 'eFG%'),
    ('Basic_Stats', 'FGA/100'),
    ('Basic_Stats', 'FG2%'),
    ('Basic_Stats', 'FG3A/100'),
    ('Basic_Stats', 'FG3%'),
    ('Basic_Stats', 'FG3ARate%'),
    ('Basic_Stats', 'RimFGA/100'),
    ('Basic_Stats', 'RimFG%'),
    ('Basic_Stats', 'FTA/100'),
    ('Basic_Stats', 'FT%'),
    ('Basic_Stats', 'FTARate%'),
    ('Basic_Stats', 'REB/100'),
    ('Basic_Stats', 'AST/100'),
    ('Basic_Stats', 'AST%'),
    ('Basic_Stats', 'BLK/100'),
    ('Basic_Stats', 'BLK%'),
    ('Basic_Stats', 'STL/100'),
    ('Basic_Stats', 'STL%'),
    ('Basic_Stats', 'TOV/100')
])

# Renaming DataFrame columns using multi-index
df_top_3_stats.columns = columns

# %%
df_top_3_stats
# Out:
#                        Player Player_info                          \
#                        Player    Position     Offensive Archetype
# 0                 Joel Embiid          C             Shot Creator
# 2       Giannis Antetokounmpo         PF             Shot Creator
# 4                Nikola Jokic          C              Post Scorer
# 1     Shai Gilgeous-Alexander         SG             Shot Creator
# 5            Donovan Mitchell         PG     Primary Ball Handler
# 3                 Luka Doncic         PG             Shot Creator
# 7               Kawhi Leonard         PF             Shot Creator
# 12               Jayson Tatum         PF             Shot Creator
# 9                Kevin Durant         PF             Shot Creator
# 8                LeBron James         SF             Shot Creator
# 10               Devin Booker         PG             Shot Creator
# 25               James Harden         PG             Shot Creator
# 20              Anthony Davis          C              Post Scorer
# 11                Paul George         SF             Shot Creator
# 6           Tyrese Haliburton         PG     Primary Ball Handler
# 26               Kyrie Irving         SG             Shot Creator
# 14              Jalen Brunson         PG     Primary Ball Handler
# 21          Victor Wembanyama          C              Stretch Big
# 18             Damian Lillard         PG     Primary Ball Handler
# 15              Derrick White         SG         Movement Shooter
# 17         Kristaps Porzingis          C            Versatile Big
# 13              Stephen Curry         PG     Primary Ball Handler
# 19               Jimmy Butler         PF             Shot Creator
# 23               De'Aaron Fox         PG     Primary Ball Handler
# 28            Lauri Markkanen         PF       Off Screen Shooter
# 16            Anthony Edwards         SG             Shot Creator
# 39               Jusuf Nurkic          C              Post Scorer
# 43                Rudy Gobert          C           Roll + Cut Big
# 22              Chet Holmgren          C              Stretch Big
# 24              Fred VanVleet         PG     Primary Ball Handler
# 27               Tyrese Maxey         PG     Primary Ball Handler
# 50              Jarrett Allen          C           Roll + Cut Big
# 34               Jaylen Brown         SF             Shot Creator
# 41         Karl-Anthony Towns         PF              Stretch Big
# 40               Jamal Murray         PG             Shot Creator
# 30         Isaiah Hartenstein          C           Roll + Cut Big
# 54             Jonathan Isaac         PF              Stretch Big
# 32            Khris Middleton         SF             Shot Creator
# 31               Franz Wagner         SF   Secondary Ball Handler
# 37                LaMelo Ball         PG     Primary Ball Handler
# 58                  Ja Morant         PG   Secondary Ball Handler
# 56              Julius Randle         PF             Shot Creator
# 35           Domantas Sabonis          C           Roll + Cut Big
# 42                 Trae Young         PG     Primary Ball Handler
# 64             Draymond Green          C              Stretch Big
# 49             Brandon Ingram         SF             Shot Creator
# 55               Aaron Gordon         PF             Shot Creator
# 77                Bam Adebayo          C             Shot Creator
# 62              Pascal Siakam         PF             Shot Creator
# 52             Scottie Barnes         SF       Stationary Shooter
# 33               Desmond Bane         SF     Primary Ball Handler
# 57               Myles Turner          C              Stretch Big
# 46             Alperen Sengun          C             Shot Creator
# 59               Goga Bitadze          C           Roll + Cut Big
# 61          Bogdan Bogdanovic         SG         Movement Shooter
# 51                Alex Caruso         SF       Stationary Shooter
# 93                Brook Lopez          C              Stretch Big
# 73          De'Anthony Melton         SG   Secondary Ball Handler
# 45              Collin Sexton         SG     Primary Ball Handler
# 53              Herbert Jones         SG       Stationary Shooter
# 29             Jalen Williams         PF     Primary Ball Handler
# 88                CJ McCollum         PG     Primary Ball Handler
# 63                 Chris Paul         PG     Primary Ball Handler
# 75                Mike Conley         PG       Stationary Shooter
# 71         Michael Porter Jr.         SF         Movement Shooter
# 96          Jaren Jackson Jr.          C             Shot Creator
# 85          Mitchell Robinson          C           Roll + Cut Big
# 67                Ivica Zubac          C           Roll + Cut Big
# 126              Jakob Poeltl          C           Roll + Cut Big
# 74               Jrue Holiday         PG       Stationary Shooter
# 36                 Kevin Love          C              Stretch Big
# 48                Evan Mobley         PF           Roll + Cut Big
# 118            Andre Drummond          C           Roll + Cut Big
# 76             Day'Ron Sharpe          C           Roll + Cut Big
# 80           Donte DiVincenzo         SG         Movement Shooter
# 87             Isaiah Jackson          C           Roll + Cut Big
# 83            Trey Murphy III         SF         Movement Shooter
# 66                  Max Strus         SF         Movement Shooter
# 47                Jalen Suggs         SG       Stationary Shooter
# 133             Tobias Harris         PF             Shot Creator
# 116           Cameron Johnson         SF       Stationary Shooter
# 44               Marcus Smart         PG   Secondary Ball Handler
# 120         Jonas Valanciunas          C              Post Scorer
# 60            Zion Williamson         PF             Shot Creator
# 174               Nic Claxton          C           Roll + Cut Big
# 82           D'Angelo Russell         PG     Primary Ball Handler
# 115            T.J. McConnell         PG     Primary Ball Handler
# 113                 Dean Wade         PF       Stationary Shooter
# 90              Jose Alvarado         PG         Movement Shooter
# 140            Walker Kessler          C           Roll + Cut Big
# 84              Mark Williams          C           Roll + Cut Big
# 69           Dereck Lively II          C           Roll + Cut Big
# 111              Clint Capela          C           Roll + Cut Big
# 108            Paolo Banchero         PF             Shot Creator
# 127            Darius Garland         PG     Primary Ball Handler
# 89             Daniel Gafford          C           Roll + Cut Big
# 81         Wendell Carter Jr.          C              Stretch Big
# 38                 OG Anunoby         SF       Stationary Shooter
# 100             DeMar DeRozan         SF             Shot Creator
# 79              Mikal Bridges         SF   Secondary Ball Handler
# 166                 Paul Reed          C           Roll + Cut Big
# 160          Payton Pritchard         PG         Movement Shooter
# 129         Immanuel Quickley         PG   Secondary Ball Handler
# 65                Jalen Smith          C              Stretch Big
# 136         Spencer Dinwiddie         PG             Shot Creator
# 99                  Kris Dunn         PG   Secondary Ball Handler
# 78              Moritz Wagner          C           Roll + Cut Big
# 98              Keegan Murray         SF         Movement Shooter
# 154             Dwight Powell          C           Roll + Cut Big
# 114  Kentavious Caldwell-Pope         SG         Movement Shooter
# 187             Kevin Huerter         SG         Movement Shooter
# 142                Sam Hauser         SF         Movement Shooter
# 94                 Duop Reath          C              Stretch Big
# 104           Dejounte Murray         SG     Primary Ball Handler
# 117               Isaac Okoro         SF       Stationary Shooter
# 121               Buddy Hield         SG         Movement Shooter
# 163             Dyson Daniels         SG       Stationary Shooter
# 106             Amen Thompson         SG        Athletic Finisher
# 143               Dario Saric          C              Stretch Big
# 175             Grayson Allen         SF       Stationary Shooter
# 244              Kevon Looney          C           Roll + Cut Big
# 138      Trayce Jackson-Davis          C           Roll + Cut Big
# 181               Ben Simmons         PG             Shot Creator
# 119                Dante Exum         SG       Stationary Shooter
# 103               Sam Merrill         SG       Off Screen Shooter
# 91                Tyler Herro         SG   Secondary Ball Handler
# 164                Al Horford          C              Stretch Big
# 183               Josh Okogie         SF        Athletic Finisher
# 109             Aaron Nesmith         SF         Movement Shooter
# 102                Tari Eason         PF        Athletic Finisher
# 220                 Josh Hart         SF       Stationary Shooter
# 182             Jalen Johnson         PF        Athletic Finisher
# 72            Malcolm Brogdon         PG     Primary Ball Handler
# 196             Chris Boucher         PF              Stretch Big
# 130                Coby White         PG         Movement Shooter
# 122               Zach LaVine         SG   Secondary Ball Handler
# 167                Isaiah Joe         SF         Movement Shooter
# 169            Xavier Tillman          C           Roll + Cut Big
# 112              Caris LeVert         SG   Secondary Ball Handler
# 162              Ryan Rollins         PG                  Slasher
# 70          Scotty Pippen Jr.         PG   Secondary Ball Handler
# 86           Jonathan Kuminga         PF        Athletic Finisher
# 145         Russell Westbrook         PG             Shot Creator
# 132                  Naz Reid          C       Stationary Shooter
# 157                Malik Monk         SG   Secondary Ball Handler
# 319                  Alex Len          C           Roll + Cut Big
# 134        Brandin Podziemski         SG       Stationary Shooter
# 146                Kyle Lowry         PG         Movement Shooter
# 180         Jordan McLaughlin         PG         Movement Shooter
# 200           Larry Nance Jr.          C              Stretch Big
# 144          Robert Covington         SF              Stretch Big
# 150           Duncan Robinson         SF         Movement Shooter
# 97                  Tre Jones         PG     Primary Ball Handler
# 201            Gary Payton II         SG              Stretch Big
# 92           Dennis Smith Jr.         PG   Secondary Ball Handler
# 179              Jared Butler         PG             Shot Creator
# 219             Austin Reaves         SG     Primary Ball Handler
# 207               Moses Moody         SF        Athletic Finisher
# 205       Talen Horton-Tucker         PG     Primary Ball Handler
# 216               Luke Kornet          C           Roll + Cut Big
# 264              Delon Wright         PG   Secondary Ball Handler
# 137             Malik Beasley         SG         Movement Shooter
# 161              Luke Kennard         SG         Movement Shooter
# 186           Anfernee Simons         SG             Shot Creator
# 147                   Bol Bol         PF        Athletic Finisher
# 232                Keon Ellis         SG       Stationary Shooter
# 302            Charles Bassey          C           Roll + Cut Big
# 123               Deni Avdija         PF        Athletic Finisher
# 159             Klay Thompson         SF       Off Screen Shooter
# 253     Sandro Mamukelashvili          C              Stretch Big
# 224           James Bouknight         PG   Secondary Ball Handler
# 101              Bradley Beal         PG   Secondary Ball Handler
# 135                Obi Toppin         PF              Stretch Big
# 387       Robert Williams III          C           Roll + Cut Big
# 176               Jalen Duren          C           Roll + Cut Big
# 215              Cam Whitmore         SF         Movement Shooter
# 172            Nikola Vucevic          C              Post Scorer
# 212            Onyeka Okongwu          C           Roll + Cut Big
# 95         Vince Williams Jr.         SG       Stationary Shooter
# 68              Devin Vassell         SF   Secondary Ball Handler
# 149             Neemias Queta          C           Roll + Cut Big
# 141       Dorian Finney-Smith         PF       Stationary Shooter
# 192           Dennis Schroder         PG     Primary Ball Handler
# 206              Caleb Martin         SF       Stationary Shooter
# 237          Kenrich Williams         PF        Athletic Finisher
# 249            Eugene Omoruyi         PF              Stretch Big
# 252           Jaylin Williams          C              Stretch Big
# 152            Ausar Thompson         SF        Athletic Finisher
# 288           Devonte' Graham         PG   Secondary Ball Handler
# 131           Cade Cunningham         SG     Primary Ball Handler
# 151              Terry Rozier         PG     Primary Ball Handler
# 198              Nikola Jovic         PF        Athletic Finisher
# 218              Kelly Olynyk          C              Stretch Big
# 158          Tristan Thompson          C           Roll + Cut Big
# 257             Kyle Anderson         SF        Athletic Finisher
# 128                RJ Barrett         SF       Stationary Shooter
# 188         Derrick Jones Jr.         PF       Stationary Shooter
# 110          Lonnie Walker IV         SG   Secondary Ball Handler
# 236              John Collins          C              Stretch Big
# 300              John Konchar         SG        Athletic Finisher
# 105  Nickeil Alexander-Walker         SG       Stationary Shooter
# 139             Naji Marshall         PF       Stationary Shooter
# 299            Jordan Goodwin         PG       Stationary Shooter
# 222         Jarred Vanderbilt         PF           Roll + Cut Big
# 203             Mason Plumlee          C           Roll + Cut Big
# 256              Cole Anthony         PG     Primary Ball Handler
# 156           Jaden McDaniels         SF       Stationary Shooter
# 229               Gary Harris         SG         Movement Shooter
# 336             Jarace Walker         PF       Stationary Shooter
# 107             Luguentz Dort         SF         Movement Shooter
# 202             Royce O'Neale         PF       Stationary Shooter
# 309          Craig Porter Jr.         PG   Secondary Ball Handler
# 223             Davis Bertans         PF         Movement Shooter
# 310               Dalen Terry         SF       Stationary Shooter
# 261           Dominick Barlow         PF        Athletic Finisher
# 278           Trendon Watford         PF                  Slasher
# 283               Nate Hinton         SG               Low Minute
# 311              Bobby Portis          C              Post Scorer
# 148             Deandre Ayton          C              Post Scorer
# 209             Norman Powell         SF         Movement Shooter
# 389              Monte Morris         PG       Stationary Shooter
# 241         Haywood Highsmith         PF       Stationary Shooter
# 228            Oshae Brissett         PF              Stretch Big
# 170                Tyus Jones         PG     Primary Ball Handler
# 266            Christian Wood         PF              Stretch Big
# 213         Julian Champagnie         SF         Movement Shooter
# 227          Jaime Jaquez Jr.         SG                  Slasher
# 173             Rui Hachimura         PF       Stationary Shooter
# 303                 Saben Lee         PG   Secondary Ball Handler
# 204               Josh Giddey         PG   Secondary Ball Handler
# 351              Anthony Gill          C        Athletic Finisher
# 243             Miles McBride         PG   Secondary Ball Handler
# 191           Kelly Oubre Jr.         SF        Athletic Finisher
# 324          Orlando Robinson          C           Roll + Cut Big
# 178             Nicolas Batum         SF        Athletic Finisher
# 245           Harrison Barnes         PF       Stationary Shooter
# 316                Vit Krejci         SF                      NaN
# 263                Trey Lyles         PF        Athletic Finisher
# 210         Marvin Bagley III         PF           Roll + Cut Big
# 306                  Mo Bamba          C           Roll + Cut Big
# 304             Jacob Gilyard         PG       Stationary Shooter
# 208              Santi Aldama         PF       Stationary Shooter
# 239          Tim Hardaway Jr.         SF         Movement Shooter
# 197                Saddiq Bey         PF        Athletic Finisher
# 301                Gui Santos         SG               Low Minute
# 195             Aaron Wiggins         SF              Stretch Big
# 366           Otto Porter Jr.         SF       Stationary Shooter
# 265             Jae'Sean Tate         SF        Athletic Finisher
# 165          Jabari Smith Jr.         PF              Stretch Big
# 184          Patrick Williams         PF       Stationary Shooter
# 155             Dillon Brooks         SF       Stationary Shooter
# 171             Miles Bridges         PF             Shot Creator
# 247            Quentin Grimes         SG         Movement Shooter
# 233           De'Andre Hunter         SF       Stationary Shooter
# 251              Jock Landale          C           Roll + Cut Big
# 125            Isaiah Stewart         PF              Stretch Big
# 240            Moussa Diabate          C           Roll + Cut Big
# 214             Cason Wallace         PG       Stationary Shooter
# 317            Richaun Holmes          C           Roll + Cut Big
# 255          Matisse Thybulle         SF       Stationary Shooter
# 189               Cody Martin         SF   Secondary Ball Handler
# 194          Precious Achiuwa         PF        Athletic Finisher
# 248               Cam Reddish         SG       Stationary Shooter
# 272              Terance Mann         SG        Athletic Finisher
# 385               Josh Minott         SF               Low Minute
# 367              Noah Clowney         PF               Low Minute
# 282             Jontay Porter          C              Stretch Big
# 124         Simone Fontecchio         SF         Movement Shooter
# 226             Aaron Holiday         PG   Secondary Ball Handler
# 294            Thaddeus Young          C           Roll + Cut Big
# 267                Joe Ingles         SF   Secondary Ball Handler
# 293          Lindy Waters III         SF         Movement Shooter
# 235                Alec Burks         SG   Secondary Ball Handler
# 291          Danilo Gallinari         PF              Stretch Big
# 323            Markelle Fultz         PG           Roll + Cut Big
# 328               Cody Zeller          C           Roll + Cut Big
# 378                 Matt Hurt         PF               Low Minute
# 405                Jamal Cain         SG              Stretch Big
# 260            Sasha Vezenkov         PF        Athletic Finisher
# 193            Toumani Camara         SF              Stretch Big
# 246               Eric Gordon         SG       Stationary Shooter
# 330              Keon Johnson         PG               Low Minute
# 331            Bruno Fernando          C           Roll + Cut Big
# 320              Jake LaRavia         SF         Movement Shooter
# 341           Harry Giles III          C           Roll + Cut Big
# 217                GG Jackson         PF       Stationary Shooter
# 250               Bruce Brown         SG   Secondary Ball Handler
# 348               A.J. Lawson         SG       Stationary Shooter
# 153           Andrew Nembhard         SG     Primary Ball Handler
# 390               Moses Brown          C           Roll + Cut Big
# 391                 Dru Smith         PG   Secondary Ball Handler
# 230               Jalen Green         SG     Primary Ball Handler
# 360               T.J. Warren         SF                      NaN
# 322              Jevon Carter         PG         Movement Shooter
# 364          Keita Bates-Diop         PF        Athletic Finisher
# 238                Cam Thomas         SG             Shot Creator
# 357               Kris Murray         PF       Stationary Shooter
# 199            Gary Trent Jr.         SG         Movement Shooter
# 231           P.J. Washington         PF              Stretch Big
# 298             Landry Shamet         SG       Off Screen Shooter
# 305            Andrew Wiggins         SF        Athletic Finisher
# 313            Trevelin Queen         SG        Athletic Finisher
# 384       Patrick Baldwin Jr.         PF              Stretch Big
# 417        Kenneth Lofton Jr.          C              Post Scorer
# 442     Juan Toscano-Anderson         SF              Stretch Big
# 377             Thomas Bryant          C           Roll + Cut Big
# 401              Damian Jones          C           Roll + Cut Big
# 318              Drew Eubanks          C           Roll + Cut Big
# 418           Lester Quinones         SF         Movement Shooter
# 441           Jerome Robinson         SG               Low Minute
# 258             Cameron Payne         PG       Stationary Shooter
# 359             Chimezie Metu         PF              Stretch Big
# 297            Grant Williams         PF       Stationary Shooter
# 394     Javon Freeman-Liberty         PG               Low Minute
# 225               Ayo Dosunmu         SG       Stationary Shooter
# 339             Stanley Umude         SF       Stationary Shooter
# 326             Georges Niang         PF         Movement Shooter
# 268            Taurean Prince         SF       Stationary Shooter
# 285                Josh Green         SF       Stationary Shooter
# 234            Keldon Johnson         PF       Stationary Shooter
# 177             Peyton Watson         SF        Athletic Finisher
# 221                  Tre Mann         PG   Secondary Ball Handler
# 363             Ashton Hagans         SG                      NaN
# 369               Kobe Bufkin         PG               Low Minute
# 273          Terquavion Smith         PG               Low Minute
# 349             Dalano Banton         SF        Athletic Finisher
# 321              JaVale McGee          C           Roll + Cut Big
# 254          Patrick Beverley         PG     Primary Ball Handler
# 379             Armoni Brooks         SG       Off Screen Shooter
# 362              Ben Sheppard         SG       Stationary Shooter
# 168                Kyle Kuzma         PF   Secondary Ball Handler
# 376             Evan Fournier         SF               Low Minute
# 335             Nate Williams         SG                  Slasher
# 269               Jae Crowder         SF       Stationary Shooter
# 333               Jaden Hardy         SG   Secondary Ball Handler
# 242                  AJ Green         SG       Stationary Shooter
# 280           Jordan Clarkson         SG             Shot Creator
# 190              Jerami Grant         PF             Shot Creator
# 343               Cole Swider         PF               Low Minute
# 275             Nick Richards          C           Roll + Cut Big
# 373              Jalen Wilson         PF        Athletic Finisher
# 421           Kessler Edwards         SF        Athletic Finisher
# 185                Jaden Ivey         PG   Secondary Ball Handler
# 381             Onuralp Bitim         SF               Low Minute
# 281             Caleb Houstan         SG         Movement Shooter
# 420              Mike Muscala          C              Stretch Big
# 270              Chris Duarte         SG         Movement Shooter
# 277              Torrey Craig         PF        Athletic Finisher
# 371          Taylor Hendricks         PF                     #N/A
# 287             Marcus Sasser         SG   Secondary Ball Handler
# 325          Collin Gillespie         PG   Secondary Ball Handler
# 292           Bismack Biyombo         PF           Roll + Cut Big
# 414               Chuma Okeke         PF         Movement Shooter
# 425         Admiral Schofield         PF               Low Minute
# 426          Brandon Williams         PG               Low Minute
# 259            Gordon Hayward         PF   Secondary Ball Handler
# 386              Blake Wesley         SG   Secondary Ball Handler
# 346              Jordan Nwora         PF       Stationary Shooter
# 457              Luka Samanic         PF              Stretch Big
# 408             Johnny Juzang         PF               Low Minute
# 423              Rayan Rupert         SG       Stationary Shooter
# 296              Daniel Theis          C           Roll + Cut Big
# 444               Leaky Black         SF       Stationary Shooter
# 211            Brandon Miller         SG   Secondary Ball Handler
# 284             Anthony Black         PG        Athletic Finisher
# 445          Brice Sensabaugh         SF               Low Minute
# 403               Maxi Kleber          C              Stretch Big
# 453             Justin Minaya         SF        Athletic Finisher
# 400         Kenyon Martin Jr.         PF                      NaN
# 262             Corey Kispert         SF       Off Screen Shooter
# 290          Bojan Bogdanovic         PF   Secondary Ball Handler
# 295             Jabari Walker         SF              Stretch Big
# 340              Jaxson Hayes          C           Roll + Cut Big
# 406               Braxton Key         PF               Low Minute
# 404            Jaden Springer         SG        Athletic Finisher
# 308            Vasilije Micic         SG   Secondary Ball Handler
# 424               Robin Lopez          C               Low Minute
# 428           Pat Connaughton         SF       Stationary Shooter
# 451              Trey Jemison          C               Low Minute
# 314             Lamar Stevens         SF        Athletic Finisher
# 271                 Matt Ryan         SF         Movement Shooter
# 329               Skylar Mays         PG   Secondary Ball Handler
# 409              Gabe Vincent         PG   Secondary Ball Handler
# 315            DeAndre Jordan          C           Roll + Cut Big
# 307          Ricky Council IV         SF               Low Minute
# 397            Dereon Seabron         SG        Athletic Finisher
# 465           Jalen McDaniels         SF       Stationary Shooter
# 350                Seth Curry         SG         Movement Shooter
# 440              R.J. Hampton         SG       Stationary Shooter
# 375      Jermaine Samuels Jr.         PF               Low Minute
# 312              Zach Collins          C            Versatile Big
# 450   Olivier-Maxence Prosper         PF       Stationary Shooter
# 383             Ousmane Dieng         PF       Stationary Shooter
# 415            Garrett Temple         SG        Athletic Finisher
# 337            Justin Holiday         SG         Movement Shooter
# 430           Julian Phillips         SF       Stationary Shooter
# 286              Derrick Rose         PG   Secondary Ball Handler
# 396            Troy Brown Jr.         SF         Movement Shooter
# 454                Seth Lundy         PF         Movement Shooter
# 460                Joe Harris         PF         Movement Shooter
# 468            Omer Yurtseven          C           Roll + Cut Big
# 469            Jamaree Bouyea         PG   Secondary Ball Handler
# 447               Colby Jones         SF         Movement Shooter
# 372             Jaylen Nowell         PG   Secondary Ball Handler
# 410              Jericho Sims          C           Roll + Cut Big
# 473              Theo Maledon         SG       Stationary Shooter
# 459                Ibou Badji          C           Roll + Cut Big
# 422              Terry Taylor         PF        Athletic Finisher
# 382            Svi Mykhailiuk         SF         Movement Shooter
# 370               Patty Mills         PG         Movement Shooter
# 274              Jordan Poole         SG     Primary Ball Handler
# 361           Josh Richardson         SG         Movement Shooter
# 395             Jalen Pickett         PG   Secondary Ball Handler
# 338             Kevin Knox II         PF       Stationary Shooter
# 332               Amir Coffey         PF       Stationary Shooter
# 471                AJ Griffin         SF         Movement Shooter
# 413            Udoka Azubuike          C           Roll + Cut Big
# 345            Bryce McGowens         SG         Movement Shooter
# 279            Reggie Jackson         PG     Primary Ball Handler
# 439          Chris Livingston         SF        Athletic Finisher
# 347              Olivier Sarr          C              Stretch Big
# 419               Cory Joseph         PG         Movement Shooter
# 353             Killian Hayes         PG     Primary Ball Handler
# 402    Jeremiah Robinson-Earl         PF              Stretch Big
# 416              Max Christie         SG       Stationary Shooter
# 342           Christian Braun         SF       Stationary Shooter
# 344           Ziaire Williams         SG       Stationary Shooter
# 432          Garrison Mathews         SG         Movement Shooter
# 399            Doug McDermott         SF       Off Screen Shooter
# 463               Emoni Bates         SF         Movement Shooter
# 380           Wesley Matthews         SF         Movement Shooter
# 276             Jeremy Sochan         SG        Athletic Finisher
# 388         Marcus Morris Sr.         PF              Stretch Big
# 289            Shaedon Sharpe         SG   Secondary Ball Handler
# 365            Jordan Hawkins         SG         Movement Shooter
# 448             Trent Forrest         PG   Secondary Ball Handler
# 458            Kira Lewis Jr.         PG   Secondary Ball Handler
# 356          Danuel House Jr.         PF         Movement Shooter
# 368                Cedi Osman         SF       Stationary Shooter
# 358              Bones Hyland         PG             Shot Creator
# 470                Taj Gibson          C           Roll + Cut Big
# 477       Jalen Hood-Schifino         PG   Secondary Ball Handler
# 392          Julian Strawther         SG       Off Screen Shooter
# 374              Ochai Agbaji         SF         Movement Shooter
# 472              Johnny Davis         SG        Athletic Finisher
# 352             Nassir Little         SF       Stationary Shooter
# 455           Markieff Morris          C              Stretch Big
# 355             James Wiseman          C           Roll + Cut Big
# 334            Keyonte George         PG     Primary Ball Handler
# 393           Tosan Evbuomwan         SF                      NaN
# 467                Kobe Brown         PF       Stationary Shooter
# 327                Jeff Green          C              Stretch Big
# 475             Maxwell Lewis         SF   Secondary Ball Handler
# 443             Yuta Watanabe         SF         Movement Shooter
# 431             Malachi Flynn         PG   Secondary Ball Handler
# 429               Gradey Dick         SF         Movement Shooter
# 354        Bennedict Mathurin         SF   Secondary Ball Handler
# 427            Furkan Korkmaz         SG   Secondary Ball Handler
# 452        Aleksej Pokusevski         PF         Movement Shooter
# 461             Isaiah Livers         SF       Stationary Shooter
# 407           Davion Mitchell         PG   Secondary Ball Handler
# 434               P.J. Tucker         PF        Athletic Finisher
# 398                Zeke Nnaji          C           Roll + Cut Big
# 456    Thanasis Antetokounmpo         PF              Post Scorer
# 438        Brandon Boston Jr.         SG   Secondary Ball Handler
# 464        Reggie Bullock Jr.         SG         Movement Shooter
# 446              Shake Milton         SG   Secondary Ball Handler
# 467  64.6%    17.9%     9.2     3.2   9.2%     0.7  0.8%     1.3  1.3%     1.8
# 327  78.0%    35.2%     6.4     3.1   8.7%     1.1  1.2%     0.8  0.8%     1.7
# 475  68.5%    22.1%     7.0     2.9   8.6%     0.7  0.7%     1.4  1.4%     2.6
# 443  63.2%    17.9%     6.4     3.0   8.8%     0.8  0.9%     1.3  1.3%     1.7
# 431  75.1%    14.9%     6.2     6.8  22.6%     0.4  0.5%     1.7  1.8%     3.1
# 429  81.5%    13.6%     5.6     3.0   7.9%     0.2  0.2%     1.4  1.4%     1.3
# 354  82.8%    38.0%     7.0     4.0  13.6%     0.6  0.6%     1.1  1.1%     3.2
# 427    NaN      NaN     NaN     NaN    NaN     NaN   NaN     NaN   NaN     NaN
# 452  66.9%    16.4%    11.1     4.0  11.8%     2.3  2.4%     1.3  1.3%     2.7
# 461  72.1%    16.7%     6.2     3.1   8.8%     0.8  0.9%     1.3  1.3%     1.5
# 407  77.3%    11.0%     3.9     5.7  15.3%     0.3  0.3%     1.2  1.2%     1.7
# 434  68.8%     8.4%     9.3     2.3   5.8%     0.6  0.6%     1.4  1.4%     1.2
# 398  69.8%    36.9%    11.1     2.6   7.6%     3.0  3.3%     1.3  1.4%     2.5
# 456  49.5%    26.7%     8.4     4.1  11.1%     1.1  1.1%     1.6  1.5%     2.7
# 438  77.8%    23.5%     6.2     2.9   8.2%     0.6  0.7%     1.4  1.5%     2.4
# 464    NaN      NaN     NaN     NaN    NaN     NaN   NaN     NaN   NaN     NaN
# 446  79.7%    19.4%     6.1     5.5  15.4%     0.5  0.6%     1.2  1.2%     2.5
# 412  72.5%    27.8%     6.9     3.1   8.2%     1.1  1.2%     1.4  1.4%     2.2
# 436  67.0%    14.0%     9.1     2.0   5.5%     1.9  2.0%     1.0  1.0%     1.5
# 466  72.5%    20.8%     7.4     4.3  12.8%     0.4  0.4%     1.5  1.5%     2.3
# 433  68.4%    17.3%     9.4     4.1  11.6%     0.6  0.6%     1.4  1.5%     2.3
# 411  68.0%    18.4%     8.9     3.8  11.3%     0.5  0.6%     1.1  1.1%     2.6
# 435  71.0%    18.1%     8.1     2.8   7.8%     0.5  0.6%     1.2  1.3%     2.3
# 437  77.6%    31.1%     5.3     8.7  26.7%     0.3  0.4%     1.2  1.2%     5.1
# 476    NaN      NaN     NaN     NaN    NaN     NaN   NaN     NaN   NaN     NaN
# 449  88.4%    11.4%     4.9     4.9  14.2%     0.3  0.4%     1.0  1.0%     2.5
# 474    NaN      NaN     NaN     NaN    NaN     NaN   NaN     NaN   NaN     NaN
# 462  77.4%     8.1%     5.0     4.2  13.2%     0.4  0.5%     1.1  1.1%     2.6

# %% [markdown]
# ## Saving the table (if needed)

# %%
# Get the current date
current_date = datetime.datetime.now().strftime("%Y-%m-%d")

# Create a file name with the current date for Excel format
file_name_excel = f"top_3_basket_stats_{current_date}.xlsx"

# Create a file name with the current date for CSV format
file_name_csv = f"top_3_basket_stats_{current_date}.csv"

# %%
# Save the DataFrame to a CSV file with the specified file name and path. If you are using the code, please specify the actual file path
# df_top_3_stats.to_csv(f"/Users/andrejviflyancev/Desktop/{file_name_csv}", index=False)

# Save the DataFrame to an Excel file with the specified file name and path. If you are using the code, please specify the actual file path
# df_top_3_stats.to_excel(f"/Users/andrejviflyancev/Desktop/{file_name_excel}", index=False)
